# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
OECD_data1 = pd.read_csv('/Users/sabrinarubert/Git/femaleEntrepreneurship/Data/OECD_Entrepreneurship_shareOfEmloyed.csv')
OECD_data1.head(10)
# Out:
#   LOCATION    Country INDICATOR  \
# 0      AUS  Australia      ENT2
# 1      AUS  Australia      ENT2
# 2      AUS  Australia      ENT2
# 3      AUS  Australia      ENT2
# 4      AUS  Australia      ENT2
# 5      AUS  Australia      ENT2
# 6      AUS  Australia      ENT2
# 7      AUS  Australia      ENT2
# 8      AUS  Australia      ENT2
# 9      AUS  Australia      ENT2
#
#                                            Indicator  SEX  Sex    AGE    Age  \
# 0  Share of self-employed who are own-account wor...  MEN  Men  TOTAL  Total
# 1  Share of self-employed who are own-account wor...  MEN  Men  TOTAL  Total
# 2  Share of self-employed who are own-account wor...  MEN  Men  TOTAL  Total
# 3  Share of self-employed who are own-account wor...  MEN  Men  TOTAL  Total
# 4  Share of self-employed who are own-account wor...  MEN  Men  TOTAL  Total
# 5  Share of self-employed who are own-account wor...  MEN  Men  TOTAL  Total
# ...
